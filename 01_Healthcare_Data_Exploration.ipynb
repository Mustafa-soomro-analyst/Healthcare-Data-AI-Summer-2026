# %% [markdown]
# <a href="https://colab.research.google.com/github/Mustafa-soomro-analyst/Healthcare-Data-AI-Summer-2026/blob/main/01_Healthcare_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
medical_data = {
    'Patient_ID': [101,102,103,104,105,106,107,108],
    'Age': [45,22,71,34,65,58,19,82],
    'Gender': ['M','F','M','F','M','F','M','F'],
    'Condition': ['Diabetes', 'Influenza', 'Heart Disease', 'Diabetes','Heart Disease', 'Ínfluenza', 'Apendicitis', 'Heart Disease'],
    'Admission_Type':['Elective', 'Emergency', 'Emergency', 'Urgent', 'Emergency', 'Urgent', 'Emergency', 'Elective'],
    'Billing_Amount_USD': [1200, 450, 8500, 1500, 9200, 600, 3100, 7800]
}

df = pd.DataFrame(medical_data)

print("--- Healthcare Dataset Preview---")
print(df.head())

print("\n--- Basic Medical Data Insights---")
print(f"Average Patient Age: {df['Age'].mean()} years old")
print(f"Total Hospital Revenue: ${df['Billing_Amount_USD'].sum()}")

print("\n--- Patient Demographics---")
print(df['Gender'].value_counts())

print("\n--- Patient Conditions---")
print(df['Condition'].value_counts())

print("\n--- Admission Types---")
print(df['Admission_Type'].value_counts())
# Out:
# --- Healthcare Dataset Preview---
#    Patient_ID  Age Gender      Condition Admission_Type  Billing_Amount_USD
# 0         101   45      M       Diabetes       Elective                1200
# 1         102   22      F      Influenza      Emergency                 450
# 2         103   71      M  Heart Disease      Emergency                8500
# 3         104   34      F       Diabetes         Urgent                1500
# 4         105   65      M  Heart Disease      Emergency                9200
#
# --- Basic Medical Data Insights---
# Average Patient Age: 49.5 years old
# Total Hospital Revenue: $32350
#
# --- Patient Demographics---
# Gender
# M    4
# F    4
# Name: count, dtype: int64
#
# --- Patient Conditions---
# Condition
# Heart Disease    3
# Diabetes         2
# Influenza        1
# Ínfluenza        1
# Apendicitis      1
# Name: count, dtype: int64
#
# --- Admission Types---
# Admission_Type
# Emergency    4
# Elective     2
# Urgent       2
# Name: count, dtype: int64

# %%
average_billing_per_condition = df.groupby('Condition')['Billing_Amount_USD'].mean()
print("\n--- Average Billing Amount per Condition---")
print(average_billing_per_condition)

emergrncy_patients = df[df['Admission_Type'] == 'Emergency']
print("\n--- Emergency Patients---")
print(emergrncy_patients[['Patient_ID', 'Age', 'Condition']])
# Out:
# --- Average Billing Amount per Condition---
# Condition
# Apendicitis      3100.0
# Diabetes         1350.0
# Heart Disease    8500.0
# Influenza         450.0
# Ínfluenza         600.0
# Name: Billing_Amount_USD, dtype: float64
#
# --- Emergency Patients---
#    Patient_ID  Age      Condition
# 1         102   22      Influenza
# 2         103   71  Heart Disease
# 4         105   65  Heart Disease
# 6         107   19    Apendicitis

# %%
import pandas as pd


dataset_url = "https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv"


df = pd.read_csv(dataset_url)


print("--- Dataset Successfully Loaded! ---")
print(f"Total Patient Records: {df.shape[0]}")
print(f"Total Metrics Collected: {df.shape[1]}")


print("\n--- Clinical Attributes List ---")
print(df.columns.tolist())


print("\n--- First 5 Patient Rows ---")
print(df.head())
# Out:
# --- Dataset Successfully Loaded! ---
# Total Patient Records: 303
# Total Metrics Collected: 14
#
# --- Clinical Attributes List ---
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
#
# --- First 5 Patient Rows ---
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#filtering high cholestrol patients

high_risk_patients = df[(df['age'] > 50) & (df['chol'] > 240)]

num_high_risk = high_risk_patients.shape[0]
print(f"Number of Patients over 50 with High Cholesterol: {num_high_risk}")

max_chol = high_risk_patients['chol'].max()
print(f"Highest individulal cholesterol level in this record: {max_chol} mg/dL")
# Out:
# Number of Patients over 50 with High Cholesterol: 111
# Highest individulal cholesterol level in this record: 564 mg/dL

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#loading our cloud dataset url
dataset_url = "https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv"
df = pd.read_csv(dataset_url)

#setting style of our plot
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='chol', data=df, hue='target', palette='dark', alpha=0.8, s=80)

plt.title('Cardiovascular Health Analysis: Patient Age vs. Cholesterol')
plt.xlabel('Patient Age (Years)', fontsize=12)
plt.ylabel('Cholesterol Level (mg/dL)', fontsize=12)
plt.legend(title='Heart Disease Present', labels=['No', 'Yes'])

plt.show()

# %%
#filtering high blood pressure patients
hypertension_patients = df[(df['age'] > 50) & (df['trestbps'] > 140)]
num_high_risk2 = hypertension_patients.shape[0]
print(f"Number of Patients over 50 with High Blood Pressure: {num_high_risk2}")

max_BP = hypertension_patients['trestbps'].max()
print(f"Highest individual blood pressure level in this record: {max_BP} mm Hg")

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='trestbps', data=df, hue='target', palette='dark', alpha=0.8, s=80)

plt.title('High Blood Pressure Analysis: Patient Age vs. Blood Pressure')
plt.xlabel('Patient Age (Years)', fontsize=12)
plt.ylabel('Blood Pressure (mm Hg)', fontsize=12)
plt.legend(title='Heart Disease Present', labels=['No', 'Yes'])

plt.show()
# Out:
# Number of Patients over 50 with High Blood Pressure: 57
# Highest individual blood pressure level in this record: 200 mm Hg

# %%
import pandas as pd

dataset_url = "https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv"
df = pd.read_csv(dataset_url)

#pasting our AI extracted patient data
ai_extracted_patient = {
    "age": [82],
    "sex": [0],
    "chol": [240],
    "trestbps": [140],
    "target": [1],
}

#converting new data in a row
new_row = pd.DataFrame(ai_extracted_patient)

#adding the new patient data in the end of the dataset
updated_df = pd.concat([df, new_row], ignore_index=True)

#verifying
print("--- Updating Hospital Records with AI pipeline ---")
print(f"Origional Dataset size:{df.shape[0]} patients")
print(f"Updated Dataset size:{updated_df.shape[0]} patients")
print("\n---Newly updated patient Record---")
print(updated_df.tail(1))
# Out:
# --- Updating Hospital Records with AI pipeline ---
# Origional Dataset size:303 patients
# Updated Dataset size:304 patients
#
# ---Newly updated patient Record---
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 303   82    0 NaN       140   240  NaN      NaN      NaN    NaN      NaN
#
#      slope  ca  thal  target
# 303    NaN NaN   NaN       1
